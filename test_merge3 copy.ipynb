# %%
import cv2
import time
import json
import requests
import re
from collections import defaultdict
import numpy as np
import ipywidgets as widgets
from IPython.display import display
import warnings
import os
from pathlib import Path
from tiki.mini import TikiMini
from ultralytics import YOLO
warnings.filterwarnings('ignore', category=UserWarning)
os.environ['GST_DEBUG'] = '0'

##############################################
# 1. YOLOv8 학습 모델 로드 (가장 먼저 실행)
##############################################
model = YOLO("./best4.pt")  # 🔥 학습한 best.pt 경로 확인

##############################################
# 2. ArUco 설정
##############################################
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_50)
aruco_params = cv2.aruco.DetectorParameters()
aruco_detector = cv2.aruco.ArucoDetector(aruco_dict, aruco_params)

# Map markers to either 'point' (Alpha/Bravo/Charlie/Finish) or 'sector' (sector1..)
# Use capitalized names for dashboard payload (matches startdashboard.ipynb template)
marker_to_point = {
    1:  { 'kind': 'point',  'name': 'Alpha' },
    2:  { 'kind': 'sector', 'name': 'sector1' },
    3:  { 'kind': 'sector', 'name': 'sector2' },
    4:  { 'kind': 'sector', 'name': 'sector3' },
    5:  { 'kind': 'sector', 'name': 'sector4' },
    6:  { 'kind': 'sector', 'name': 'sector5' },
    7:  { 'kind': 'sector', 'name': 'sector6' },
    8:  { 'kind': 'point',  'name': 'Bravo' },
    9:  { 'kind': 'sector', 'name': 'sector7' },
    10: { 'kind': 'point',  'name': 'Charlie' },
    11: { 'kind': 'sector', 'name': 'sector8' },
    12: { 'kind': 'sector', 'name': 'sector9' },
    13: { 'kind': 'point',  'name': 'Finish' },
}

visited_points = set()          # internal set to avoid duplicate handling
transmitted_points = []         # ordered list to send in payload's `points` array

object_names = ['box', 'car', 'enemy', 'hazmat', 'missile', 'mortar', 'tank']

# 각 point별로 누적된 detection 정보 저장 {point_name: {class_name: count}}
point_detections = defaultdict(lambda: defaultdict(int))
current_point = None  # 현재 위치한 point (마지막으로 지나간 point)
visited_sectors = set()  # 이미 이미지를 전송한 sector 추적 (중복 전송 방지)

##############################################
# 4. 로봇 초기화
##############################################
tiki = TikiMini()
tiki.set_motor_mode(tiki.MOTOR_MODE_PWM)
# 안전: 초기화 직후 모터 정지
try:
    tiki.stop()
except Exception:
    pass
print("로봇 초기화 완료 (모터 정지)")

# 주행 파라미터
base_speed = 70
max_steering = 27
frame_center_x = 160  # 320x240 기준 중앙 X

# PID 제어
class PIDController:
    def __init__(self, kp=0.6, ki=0.0, kd=0.15):
        self.kp = kp
        self.ki = ki
        self.kd = kd
        self.integral = 0
        self.prev_error = 0

    def compute(self, error):
        self.integral += error
        derivative = error - self.prev_error
        self.prev_error = error
        self.integral = np.clip(self.integral, -200, 200)
        return self.kp * error + self.ki * self.integral + self.kd * derivative

pid = PIDController()

##############################################
# 5. 서버 전송 함수 (필요 시 사용)
##############################################
def send_to_server(point=None, detected_objects=None, points=None, fire_buildings=None):
    """Send dashboard payload. Use `points` to pass Alpha/Bravo/Charlie list.
    - `point` kept for backward compatibility (not used for point-list payloads)
    - `detected_objects` expects a dict (detection map)
    - `points` is a list of point names (capitalized) to include in payload
    - `fire_buildings` is an optional list
    - Loads base JSON from /home/jetson/Workspace/report/A3R8.json
    - Only updates `points` and `detection`, keeps `mission_code` and `fire_buildings` from file
    """
    # JSON 파일에서 기본 데이터 로드
    json_path = "/home/jetson/Workspace/report/A3R8.json"
    try:
        with open(json_path, 'r', encoding='utf-8') as f:
            base_payload = json.load(f)
    except FileNotFoundError:
        print(f"[WARNING] JSON 파일을 찾을 수 없습니다: {json_path}, 기본값 사용")
        base_payload = {
            "mission_code": "A3R8",
            "fire_buildings": [],
            "points": [],
            "detection": {}
        }
    except Exception as e:
        print(f"[ERROR] JSON 파일 읽기 실패: {e}, 기본값 사용")
        base_payload = {
            "mission_code": "A3R8",
            "fire_buildings": [],
            "points": [],
            "detection": {}
        }
    
    # mission_code와 fire_buildings는 파일에서 가져온 값 유지
    # points와 detection만 함수 파라미터로 업데이트
    # detection 형식: {point_name: [{type: class_name, count: count}, ...]}
    
    # 기존 detection과 새로운 detection 병합
    base_detection = base_payload.get("detection", {})
    if detected_objects is not None:
        # 새로운 detection을 기존 detection에 병합 (같은 point_name이면 덮어쓰기)
        merged_detection = base_detection.copy()
        for point_name, detection_list in detected_objects.items():
            merged_detection[point_name] = detection_list
        final_detection = merged_detection
    else:
        final_detection = base_detection
    
    payload = {
        "mission_code": base_payload.get("mission_code", "A3R8"),
        "fire_buildings": base_payload.get("fire_buildings", []),
        "points": points if points is not None else base_payload.get("points", []),
        "detection": final_detection
    }

    json_content = json.dumps(payload, indent=2, ensure_ascii=False)
    files = {
        'file': (f"mission_{payload['mission_code']}.json", json_content, 'application/json')
    }

    try:
        print(f"[SEND] dashboard payload → points={payload['points']} detection_keys={list(payload['detection'].keys())}")
        rsp = requests.post("http://58.229.150.23:5000/dashboard_json", files=files, timeout=10)
        print("[Server Response]", rsp.text)
        
        # 서버 전송 성공 후 JSON 파일에 payload 업데이트
        try:
            # 디렉토리가 없으면 생성
            os.makedirs(os.path.dirname(json_path), exist_ok=True)
            
            with open(json_path, 'w', encoding='utf-8') as f:
                json.dump(payload, f, indent=2, ensure_ascii=False)
            print(f"[UPDATE] JSON 파일 업데이트 완료: {json_path}")
        except Exception as e:
            print(f"[WARNING] JSON 파일 업데이트 실패: {e}")
            
    except Exception as e:
        print("[ERROR] 서버 전송 실패:", e)

##############################################
# 5-2. 이미지 전송 함수
##############################################
def send_dashboard_image(image_path):
    """대시보드로 이미지 파일 전송"""
    image_file = Path(image_path)
    
    if not image_file.exists():
        print(f"[WARNING] 이미지 파일 없음: {image_file}")
        return
    
    try:
        print(f"[SEND IMAGE] 이미지 전송 중: {image_file.name}")
        
        with open(image_file, "rb") as f:
            files = {
                'file': (image_file.name, f, 'image/jpeg')
            }
            
            response = requests.post(
                'http://58.229.150.23:5000/img/dashboard/fire_building',
                files=files,
                timeout=10
            )
        
        print(f"[SEND IMAGE] 서버 응답: {response.text}")
        
    except Exception as e:
        print(f"[ERROR] 이미지 전송 실패: {e}")

##############################################
# 6. 단일 카메라 파이프라인 (주행 + YOLO 공용)
##############################################
pipeline = (
    "nvarguscamerasrc ! "
    "video/x-raw(memory:NVMM), width=640, height=480, format=NV12, framerate=30/1 ! "
    "nvvidconv ! video/x-raw, format=BGRx ! videoconvert ! "
    "video/x-raw, format=BGR ! appsink drop=true max-buffers=1"
)

cap = cv2.VideoCapture(pipeline, cv2.CAP_GSTREAMER)
if not cap.isOpened():
    raise RuntimeError("카메라를 열 수 없습니다.")

# 최신 프레임만 사용하도록 버퍼 최소화
cap.set(cv2.CAP_PROP_BUFFERSIZE, 1)

##############################################
# 7. Jupyter용 두 화면 위젯 (주행 / 객체인식)
##############################################
drive_widget = widgets.Image(
    format='jpeg',
    layout=widgets.Layout(width='640px', height='480px')
)
yolo_widget = widgets.Image(
    format='jpeg',
    layout=widgets.Layout(width='640px', height='480px')
)

display(widgets.HBox([drive_widget, yolo_widget]))

##############################################
# 8. Bird's-Eye View 설정 (주행용)
##############################################
bird_width, bird_height = 320, 240

src_points = np.float32([
    [60, 120],
    [260, 120],
    [310, 230],
    [10, 230],
])

dst_points = np.float32([
    [0, 0],
    [bird_width - 1, 0],
    [bird_width - 1, bird_height - 1],
    [0, bird_height - 1],
])

M = cv2.getPerspectiveTransform(src_points, dst_points)


def frame_to_bytes_drive(frame):
    """주행 디버그 패널 전송용 (낮은 품질, 부하 적음)"""
    _, buf = cv2.imencode('.jpg', frame, [int(cv2.IMWRITE_JPEG_QUALITY), 30])
    return buf.tobytes()


def frame_to_bytes_yolo(frame):
    """YOLO/ArUco 시각화용 (더 높은 품질, 사람이 보기 좋게)"""
    _, buf = cv2.imencode('.jpg', frame, [int(cv2.IMWRITE_JPEG_QUALITY), 70])  # 필요시 60~80 사이에서 조절
    return buf.tobytes()


# ============================================================
#   9) 슬라이딩 윈도우 + 시각화 (주행용)
# ============================================================
def sliding_window_center_with_vis(binary_mask, num_windows=8, margin=20, min_pixels=30):
    h, w = binary_mask.shape[:2]
    window_height = h // num_windows
    ys, xs = np.where(binary_mask == 255)

    vis = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)

    if len(xs) == 0:
        return None, vis

    bottom_thresh = int(h * 0.75)
    bottom_inds = ys >= bottom_thresh
    if np.any(bottom_inds):
        current_x = int(np.mean(xs[bottom_inds]))
    else:
        current_x = int(np.mean(xs))

    centers = []
    pts = []

    for i in range(num_windows):
        y_low = h - (i + 1) * window_height
        y_high = h - i * window_height
        y_low = max(0, y_low)
        if y_high <= y_low:
            continue

        inds = (ys >= y_low) & (ys < y_high)
        win_xs = xs[inds]
        if len(win_xs) == 0:
            continue

        x_min = max(0, current_x - margin)
        x_max = min(w - 1, current_x + margin)

        lane_inds = (win_xs >= x_min) & (win_xs <= x_max)
        if np.sum(lane_inds) < min_pixels:
            continue

        current_x = int(np.mean(win_xs[lane_inds]))
        centers.append(current_x)

        cy = (y_low + y_high) // 2
        pts.append((current_x, cy))

        cv2.rectangle(vis, (x_min, y_low), (x_max, y_high), (0, 255, 0), 1)
        cv2.circle(vis, (current_x, cy), 3, (255, 0, 255), -1)

    if len(centers) == 0:
        return int(np.mean(xs)), vis

    pts_np = np.array(pts, np.int32)
    cv2.polylines(vis, [pts_np], False, (255, 0, 255), 2)

    return int(np.mean(centers)), vis


# ============================================================
#   10) 중앙 흰색 라인 + 디버그뷰 생성 (주행용)
# ============================================================
def detect_lane_center(frame_bgr, white_threshold=180):
    h, w = frame_bgr.shape[:2]

    # ROI (하단부)
    roi_y1 = int(h * 0.60)
    roi_y2 = h
    roi_x1 = int(w * 0.10)
    roi_x2 = int(w * 0.90)
    roi = frame_bgr[roi_y1:roi_y2, roi_x1:roi_x2]
    roi_h, roi_w = roi.shape[:2]

    # ① BGR -> HSV 변환
    hsv = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)

    # 흰색만 남기기 위한 조건
    S_MAX = 60
    V_MIN = 180

    lower_white = np.array([0, 0, V_MIN], dtype=np.uint8)
    upper_white = np.array([180, S_MAX, 255], dtype=np.uint8)
    white_mask = cv2.inRange(hsv, lower_white, upper_white)

    # 노란색 제거 (필요 시)
    lower_yellow = np.array([15, 80, 80], dtype=np.uint8)
    upper_yellow = np.array([40, 255, 255], dtype=np.uint8)
    yellow_mask = cv2.inRange(hsv, lower_yellow, upper_yellow)

    white_mask = cv2.bitwise_and(white_mask, cv2.bitwise_not(yellow_mask))
    white_mask = cv2.GaussianBlur(white_mask, (5, 5), 0)

    ys, xs = np.where(white_mask == 255)
    white_mask_bgr = cv2.cvtColor(white_mask, cv2.COLOR_GRAY2BGR)

    if len(xs) == 0:
        return None, False, {
            "roi": roi,
            "white": white_mask_bgr,
            "sliding": white_mask_bgr.copy(),
        }

    # 슬라이딩윈도우
    center_x_rel, sliding_vis = sliding_window_center_with_vis(white_mask)

    if center_x_rel is None:
        center_x_rel = int(np.mean(xs))

    center_x_frame = roi_x1 + center_x_rel

    # 가로 흰줄 판단 (STOP LINE 등)
    x_range = np.max(xs) - np.min(xs)
    y_range = np.max(ys) - np.min(ys)
    is_horizontal_bar = (x_range > roi_w * 0.6 and y_range < roi_h * 0.25)

    return center_x_frame, is_horizontal_bar, {
        "roi": roi,
        "white": white_mask_bgr,
        "sliding": sliding_vis,
    }


# ============================================================
#   11) 2×2 디버그 패널 생성 (주행용)
# ============================================================
def make_panel(bird, dbg):
    def R(img):
        return cv2.resize(img, (320, 240))

    panel_top = cv2.hconcat([R(bird), R(dbg["roi"])] )
    panel_bot = cv2.hconcat([R(dbg["white"]), R(dbg["sliding"])])
    return cv2.vconcat([panel_top, panel_bot])


# ------------------------------
# Improved Pothole detection (adaptive)
# ------------------------------
# Problems addressed:
# - static absolute thresholds can falsely trigger when lane white is already thin
# - use EMA baseline + relative drop + absolute minimum
# - apply small morphology open to remove noise

# state variables
pothole_counter = 0
pothole_last_time = 0.0
POTHOLE_DETECT_FRAMES = 4       # 연속 판정 프레임 수 (감도)
POTHOLE_COOLDOWN = 19.0         # 회피 후 재감지 대기(sec)
POTHOLE_MIN_ABS = 0.01          # 절대 최소 흰색 비율 (너무 작은 값이면 무시)
POTHOLE_RATIO = 0.4             # 기준(EMA) 대비 이 비율보다 작으면 포트홀로 판단
EMA_ALPHA = 0.05                # EMA 업데이트 계수 (기준 적응 속도)
baseline_white = None           # EMA baseline for white fraction

# morphology kernel
_morph_kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5,5))


def detect_pothole(frame_bgr):
    """Compute white fraction in ROI with noise filtering.
    Returns: white_frac (0..1), roi_visual, mask_visual
    """
    h, w = frame_bgr.shape[:2]
    roi_y1 = int(h * 0.60)
    roi_y2 = h
    roi_x1 = int(w * 0.10)
    roi_x2 = int(w * 0.90)
    roi = frame_bgr[roi_y1:roi_y2, roi_x1:roi_x2]

    hsv = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)

    S_MAX = 60
    V_MIN = 180
    lower_white = np.array([0, 0, V_MIN], dtype=np.uint8)
    upper_white = np.array([180, S_MAX, 255], dtype=np.uint8)
    white_mask = cv2.inRange(hsv, lower_white, upper_white)

    # 노이즈 제거: open + small closing
    white_mask = cv2.morphologyEx(white_mask, cv2.MORPH_OPEN, _morph_kernel)
    white_mask = cv2.morphologyEx(white_mask, cv2.MORPH_CLOSE, _morph_kernel)

    # optional: ignore very small components
    # (connectedComponentsWithStats could be used, but heavier)

    white_count = int(np.sum(white_mask == 255))
    total = white_mask.size
    white_frac = white_count / float(total) if total > 0 else 0.0

    white_mask_bgr = cv2.cvtColor(white_mask, cv2.COLOR_GRAY2BGR)
    return white_frac, roi, white_mask_bgr


def should_trigger_pothole(white_frac):
    """Decide based on EMA baseline + absolute minimum and ratio."""
    global baseline_white
    if baseline_white is None:
        baseline_white = white_frac
        return False

    # Update baseline conservatively when white_frac is not very low
    # This prevents fast baseline drop during true pothole events
    if white_frac > baseline_white * 0.9:
        baseline_white = EMA_ALPHA * white_frac + (1 - EMA_ALPHA) * baseline_white

    threshold = max(POTHOLE_MIN_ABS, baseline_white * POTHOLE_RATIO)
    return white_frac < threshold


def avoid_pothole_left():
    """Left avoidance: stop -> short reverse -> gentle left sweep -> stop
    Tweak timings/speeds to your robot.
    """
    global pothole_last_time
    print("[AVOID] 포트홀 회피 시작 (좌회전)")
    try:
        tiki.stop()
        time.sleep(0.12)

        # try short reverse if supported
        try:
            tiki.backward(50)
            time.sleep(0.5)
        except Exception:
            tiki.stop()
            time.sleep(0.2)

        # left sweep: left slower/backward, right forward -> gentle left
        try:
            tiki.counter_clockwise(25)
            time.sleep(1.8)
            tiki.forward(50)
            time.sleep(2)
            tiki.set_motor_power(tiki.MOTOR_LEFT, 60)
            tiki.set_motor_power(tiki.MOTOR_RIGHT, 10)
            time.sleep(1.8)
            tiki.forward(50)
            time.sleep(2)
        except Exception:
            tiki.stop()
            time.sleep(0.3)

        tiki.stop()
    except Exception as e:
        print("[AVOID][ERROR] 회피중 예외:", e)
        try:
            tiki.stop()
        except Exception:
            pass

    pothole_last_time = time.time()
    print("[AVOID] 회피 완료")

##############################################
# 12. 메인 루프 (단일 카메라 → 주행 + YOLO 두 화면 출력)
##############################################
print("[START] 주행 + YOLO + ArUco 시스템 실행")

frame_idx = 0
annotated = None  # 마지막 YOLO 결과 프레임 보관

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            time.sleep(8)
            continue

        frame_idx += 1

        # 공통 원본 프레임 (카메라 기준 회전 보정)
        frame = cv2.flip(frame, -1)

        # 주행용 처리를 위해 320x240으로 다운스케일한 프레임 사용
        frame_small = cv2.resize(frame, (bird_width, bird_height))

        # ----- (1) 주행용 버드뷰 / 차선 인식 -----
        bird = cv2.warpPerspective(frame_small, M, (bird_width, bird_height))
        center_x, is_horizontal_bar, dbg = detect_lane_center(bird)
        view = bird.copy()

        if center_x is not None:
            error = center_x - frame_center_x

            steering = pid.compute(error)
            steering *= 0.5
            steering = float(np.clip(steering, -max_steering, max_steering))
            if is_horizontal_bar:
                steering = 0

            L = int(np.clip(base_speed + steering, 0, 127))
            Rm = int(np.clip(base_speed - steering, 0, 127))

            tiki.set_motor_power(tiki.MOTOR_LEFT, L)
            tiki.set_motor_power(tiki.MOTOR_RIGHT, Rm)
        else:
            tiki.stop()

        panel = make_panel(view, dbg)

        # ----- (2) 객체 인식 (YOLO + ArUco) : N프레임마다만 수행 -----
        frame_for_aruco = frame.copy()

        # (A) ArUco 포인트 감지 (원본 해상도 사용)
        corners, ids, _ = aruco_detector.detectMarkers(frame_for_aruco)

        if ids is not None:
            ids_list = [int(i[0]) for i in ids]

            for marker_id in ids_list:
                if marker_id in marker_to_point:
                    info = marker_to_point[marker_id]
                    # only treat 'point' kinds as mission points (Alpha/Bravo/Charlie/Finish)
                    if info['kind'] == 'point':
                        point_name = info['name']
                        current_point = point_name  # 현재 point 업데이트

                        if point_name not in visited_points:
                            visited_points.add(point_name)
                            transmitted_points.append(point_name)
                            
                            # 해당 point까지의 누적 detection 정보를 detection 형식으로 변환
                            detection_for_payload = {}
                            if point_name in point_detections:
                                detection_list = []
                                for class_name, count in point_detections[point_name].items():
                                    if count > 0:  # count가 0보다 큰 경우만 추가
                                        detection_list.append({"type": class_name, "count": count})
                                if detection_list:
                                    detection_for_payload[point_name] = detection_list
                            
                            print(f"[POINT] {point_name} 최초 통과 → 대시보드로 전송 (points 업데이트, detection: {detection_for_payload})")
                            # send the accumulated points list and detection in payload
                            send_to_server(points=transmitted_points, detected_objects=detection_for_payload)
                    else:
                        # sector handling: fire_buildings에 포함된 sector면 이미지 캡처 및 전송
                        sector_name = info['name']
                        print(f"[SECTOR] 감지: {sector_name}")
                        
                        # JSON 파일에서 fire_buildings 확인
                        json_path = "/home/jetson/Workspace/report/A3R8.json"
                        try:
                            with open(json_path, 'r', encoding='utf-8') as f:
                                json_data = json.load(f)
                            
                            fire_buildings = json_data.get("fire_buildings", [])
                            mission_code = json_data.get("mission_code", "A3R8")
                            
                            # fire_buildings에 포함되어 있고, 아직 전송하지 않은 sector인 경우
                            if sector_name in fire_buildings and sector_name not in visited_sectors:
                                visited_sectors.add(sector_name)
                                
                                # sector 이름에서 숫자 추출 (예: "sector8" -> "8")
                                sector_number = re.search(r'\d+', sector_name)
                                if sector_number:
                                    section_num = sector_number.group()
                                    
                                    # 이미지 파일 이름 생성: A3R8_section8.jpg
                                    image_filename = f"{mission_code}_section{section_num}.jpg"
                                    image_path = os.path.join("/tmp", image_filename)
                                    
                                    # 현재 프레임 캡처
                                    cv2.imwrite(image_path, frame_for_aruco)
                                    print(f"[FIRE BUILDING] {sector_name} 감지 → 이미지 캡처: {image_filename}")
                                    
                                    # 서버로 이미지 전송
                                    send_dashboard_image(image_path)
                                    
                                    # 임시 파일 삭제 (선택사항)
                                    try:
                                        os.remove(image_path)
                                    except:
                                        pass
                                else:
                                    print(f"[WARNING] sector 이름에서 숫자를 추출할 수 없습니다: {sector_name}")
                        except FileNotFoundError:
                            print(f"[WARNING] JSON 파일을 찾을 수 없습니다: {json_path}")
                        except Exception as e:
                            print(f"[ERROR] fire_building 확인 중 오류: {e}")

            cv2.aruco.drawDetectedMarkers(frame_for_aruco, corners, ids)

        # (B) YOLO 객체 감지
        if frame_idx % 5 == 0:
            frame_for_yolo = frame.copy()
            results = model(
                frame_for_yolo,
                conf=0.45,
            )

            detected_counts = defaultdict(int)
            if results and len(results[0].boxes) > 0:
                classes = results[0].boxes.cls.cpu().numpy()
                for cls in classes:
                    class_name = object_names[int(cls)]
                    detected_counts[class_name] += 1
                    
                    # 현재 point에 detection 정보 누적
                    if current_point is not None:
                        point_detections[current_point][class_name] += 1
                        
            if len(detected_counts) > 0:
                print(f"[DETECTION] 객체 감지: {dict(detected_counts)} (현재 point: {current_point})")

            annotated = results[0].plot()
            cv2.putText(
                annotated,
                "Object Detection",
                (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (255, 0, 0),
                2,
                cv2.LINE_AA,
            )

        # ----- 포트홀 감지 (적응형) -----
        # 사용자 요청에 따라 YOLO/ArUco 처리가 끝난 다음에 포트홀 감지를 수행합니다.
        white_frac, _roi, _mask = detect_pothole(bird)
        trigger = should_trigger_pothole(white_frac)

        if trigger and (time.time() - pothole_last_time) > POTHOLE_COOLDOWN:
            pothole_counter += 1
        else:
            pothole_counter = 0

        if pothole_counter >= POTHOLE_DETECT_FRAMES:
            print(f"[POTHOLE] 감지: white_frac={white_frac:.3f} baseline={baseline_white:.3f} → 회피 수행")
            avoid_pothole_left()
            pothole_counter = 0

        # ----- (3) 두 화면을 Jupyter 위젯으로 출력 -----
        drive_widget.value = frame_to_bytes_drive(panel)
        if annotated is not None and frame_idx % 2 == 0:
            yolo_widget.value = frame_to_bytes_yolo(annotated)

        time.sleep(0.02)

except KeyboardInterrupt:
    tiki.stop()
    cap.release()
    cv2.destroyAllWindows()
    print("[END] 프로그램 종료")
# Out:
# 로봇 초기화 완료 (모터 정지)
# GST_ARGUS: Cleaning up
# CONSUMER: Done Success
# GST_ARGUS: Done Success
# GST_ARGUS: Creating output stream
# CONSUMER: Waiting until producer is connected...
# GST_ARGUS: Available Sensor modes :
# GST_ARGUS: 3264 x 2464 FR = 21.000000 fps Duration = 47619048 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: 3264 x 1848 FR = 28.000001 fps Duration = 35714284 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: 1920 x 1080 FR = 29.999999 fps Duration = 33333334 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: 1640 x 1232 FR = 29.999999 fps Duration = 33333334 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: 1280 x 720 FR = 59.999999 fps Duration = 16666667 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: 1280 x 720 FR = 120.000005 fps Duration = 8333333 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: Running with following settings:
#    Camera index = 0
#    Camera mode  = 5
#    Output Stream W = 1280 H = 720
#    seconds to Run    = 0
#    Frame Rate = 120.000005
# GST_ARGUS: Setup Complete, Starting captures for 0 seconds
# GST_ARGUS: Starting repeat capture requests.
# CONSUMER: Producer has connected; continuing.
# [INFO] 카메라 프레임 수신 대기 중...
# [INFO] 카메라 준비 완료
# [ WARN:0@298.703] global cap_gstreamer.cpp:1777 open OpenCV | GStreamer warning: Cannot query video position: status=0, value=-1, duration=-1
# [ WARN:0@298.708] global cap_gstreamer.cpp:2152 setProperty OpenCV | GStreamer warning: GStreamer: unhandled property
# HBox(children=(Image(value=b'', format='jpeg', layout="Layout(height='480px', width='640px')"), Image(value=b'…
# [START] 주행 + YOLO + ArUco 시스템 실행
# [POTHOLE] 감지: white_frac=0.000 baseline=0.000 → 회피 수행
# [AVOID] 포트홀 회피 시작 (좌회전)
# [AVOID] 회피 완료
#
# 0: 320x416 (no detections), 72.0ms
# Speed: 6.9ms preprocess, 72.0ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.7ms
# Speed: 6.9ms preprocess, 74.7ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.6ms
# Speed: 7.3ms preprocess, 77.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 7.0ms preprocess, 74.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 6.7ms preprocess, 74.9ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.1ms
# Speed: 6.9ms preprocess, 75.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 7.0ms preprocess, 74.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.7ms
# Speed: 7.2ms preprocess, 74.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 1 hazmat, 75.8ms
# Speed: 6.9ms preprocess, 75.8ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 (no detections), 74.7ms
# Speed: 7.3ms preprocess, 74.7ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 1 enemy, 1 mortar, 75.8ms
# Speed: 8.6ms preprocess, 75.8ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'enemy': 1, 'mortar': 1}
#
# 0: 320x416 1 hazmat, 1 mortar, 77.1ms
# Speed: 7.0ms preprocess, 77.1ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'mortar': 1, 'hazmat': 1}
#
# 0: 320x416 1 enemy, 1 hazmat, 1 mortar, 75.8ms
# Speed: 8.2ms preprocess, 75.8ms inference, 6.3ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'mortar': 1, 'enemy': 1, 'hazmat': 1}
#
# 0: 320x416 1 enemy, 1 mortar, 76.3ms
# Speed: 7.1ms preprocess, 76.3ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'mortar': 1, 'enemy': 1}
# [POINT] alpha 최초 통과 → 서버 전송
# [SEND] alpha → 서버 전송 중…
# [Server Response] {"filename":"alpha.json","message":"JSON uploaded successfully"}
#
#
# 0: 320x416 3 enemys, 1 hazmat, 1 mortar, 75.0ms
# Speed: 6.9ms preprocess, 75.0ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'mortar': 1, 'enemy': 3, 'hazmat': 1}
#
# 0: 320x416 2 enemys, 1 hazmat, 1 mortar, 75.2ms
# Speed: 6.8ms preprocess, 75.2ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'mortar': 1, 'hazmat': 1, 'enemy': 2}
#
# 0: 320x416 1 hazmat, 1 mortar, 76.4ms
# Speed: 6.9ms preprocess, 76.4ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'mortar': 1, 'hazmat': 1}
#
# 0: 320x416 1 enemy, 1 hazmat, 1 mortar, 74.7ms
# Speed: 7.7ms preprocess, 74.7ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'enemy': 1, 'mortar': 1}
# [POINT] sector1 최초 통과 → 서버 전송
# [SEND] sector1 → 서버 전송 중…
# [Server Response] {"filename":"sector1.json","message":"JSON uploaded successfully"}
#
#
# 0: 320x416 1 enemy, 1 hazmat, 140.9ms
# Speed: 11.0ms preprocess, 140.9ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'enemy': 1}
#
# 0: 320x416 2 enemys, 1 hazmat, 78.6ms
# Speed: 6.9ms preprocess, 78.6ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'enemy': 2}
#
# 0: 320x416 1 hazmat, 74.9ms
# Speed: 7.1ms preprocess, 74.9ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 enemy, 1 hazmat, 74.9ms
# Speed: 6.8ms preprocess, 74.9ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'enemy': 1}
#
# 0: 320x416 1 hazmat, 75.9ms
# Speed: 7.2ms preprocess, 75.9ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 hazmat, 74.8ms
# Speed: 6.6ms preprocess, 74.8ms inference, 6.8ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 hazmat, 1 missile, 75.0ms
# Speed: 6.9ms preprocess, 75.0ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'missile': 1}
#
# 0: 320x416 1 hazmat, 1 missile, 75.0ms
# Speed: 8.0ms preprocess, 75.0ms inference, 7.7ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'missile': 1}
#
# 0: 320x416 1 hazmat, 1 missile, 74.8ms
# Speed: 6.9ms preprocess, 74.8ms inference, 8.1ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'missile': 1}
#
# 0: 320x416 1 hazmat, 1 missile, 74.8ms
# Speed: 7.0ms preprocess, 74.8ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'missile': 1}
#
# 0: 320x416 1 hazmat, 1 missile, 76.9ms
# Speed: 7.0ms preprocess, 76.9ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'missile': 1}
#
# 0: 320x416 1 hazmat, 1 missile, 74.9ms
# Speed: 6.7ms preprocess, 74.9ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'missile': 1}
#
# 0: 320x416 1 hazmat, 1 missile, 74.8ms
# Speed: 7.2ms preprocess, 74.8ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'missile': 1}
#
# 0: 320x416 1 hazmat, 1 missile, 74.6ms
# Speed: 7.2ms preprocess, 74.6ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'missile': 1, 'hazmat': 1}
#
# 0: 320x416 1 missile, 75.1ms
# Speed: 7.0ms preprocess, 75.1ms inference, 6.3ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'missile': 1}
#
# 0: 320x416 1 missile, 75.7ms
# Speed: 7.1ms preprocess, 75.7ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'missile': 1}
#
# 0: 320x416 1 missile, 76.0ms
# Speed: 6.8ms preprocess, 76.0ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'missile': 1}
#
# 0: 320x416 1 missile, 75.0ms
# Speed: 6.9ms preprocess, 75.0ms inference, 9.7ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'missile': 1}
#
# 0: 320x416 1 missile, 74.9ms
# Speed: 6.8ms preprocess, 74.9ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'missile': 1}
#
# 0: 320x416 1 missile, 74.8ms
# Speed: 6.9ms preprocess, 74.8ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'missile': 1}
#
# 0: 320x416 1 missile, 74.8ms
# Speed: 7.6ms preprocess, 74.8ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'missile': 1}
#
# 0: 320x416 (no detections), 74.6ms
# Speed: 6.9ms preprocess, 74.6ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.2ms
# Speed: 6.9ms preprocess, 76.2ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 7.3ms preprocess, 74.9ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 6.9ms preprocess, 74.9ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.9ms
# Speed: 6.9ms preprocess, 76.9ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.4ms
# Speed: 7.7ms preprocess, 77.4ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 6.9ms preprocess, 74.9ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 6.8ms preprocess, 74.8ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 1 box, 74.8ms
# Speed: 6.8ms preprocess, 74.8ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'box': 1}
# [POINT] sector4 최초 통과 → 서버 전송
# [SEND] sector4 → 서버 전송 중…
# [Server Response] {"filename":"sector4.json","message":"JSON uploaded successfully"}
#
#
# 0: 320x416 1 box, 74.9ms
# Speed: 7.1ms preprocess, 74.9ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'box': 1}
#
# 0: 320x416 1 box, 74.8ms
# Speed: 6.7ms preprocess, 74.8ms inference, 7.7ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'box': 1}
#
# 0: 320x416 1 box, 74.8ms
# Speed: 6.9ms preprocess, 74.8ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'box': 1}
#
# 0: 320x416 1 box, 74.9ms
# Speed: 6.9ms preprocess, 74.9ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'box': 1}
#
# 0: 320x416 1 box, 76.2ms
# Speed: 6.8ms preprocess, 76.2ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'box': 1}
#
# 0: 320x416 1 box, 1 tank, 75.9ms
# Speed: 8.1ms preprocess, 75.9ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'tank': 1, 'box': 1}
#
# 0: 320x416 1 hazmat, 75.1ms
# Speed: 7.6ms preprocess, 75.1ms inference, 8.9ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 hazmat, 74.9ms
# Speed: 7.5ms preprocess, 74.9ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 hazmat, 74.9ms
# Speed: 6.9ms preprocess, 74.9ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 enemy, 1 hazmat, 1 missile, 74.6ms
# Speed: 6.7ms preprocess, 74.6ms inference, 9.7ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'enemy': 1, 'missile': 1}
#
# 0: 320x416 1 enemy, 1 hazmat, 1 missile, 74.6ms
# Speed: 7.1ms preprocess, 74.6ms inference, 8.2ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'enemy': 1, 'hazmat': 1, 'missile': 1}
#
# 0: 320x416 2 enemys, 1 hazmat, 75.0ms
# Speed: 7.2ms preprocess, 75.0ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'enemy': 2, 'hazmat': 1}
#
# 0: 320x416 1 enemy, 1 hazmat, 74.9ms
# Speed: 6.9ms preprocess, 74.9ms inference, 9.1ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'enemy': 1}
#
# 0: 320x416 1 enemy, 1 hazmat, 77.2ms
# Speed: 7.1ms preprocess, 77.2ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'enemy': 1}
#
# 0: 320x416 1 enemy, 2 hazmats, 75.9ms
# Speed: 7.4ms preprocess, 75.9ms inference, 6.3ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 2, 'enemy': 1}
#
# 0: 320x416 2 hazmats, 75.8ms
# Speed: 7.0ms preprocess, 75.8ms inference, 10.2ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 2}
#
# 0: 320x416 1 hazmat, 75.1ms
# Speed: 7.3ms preprocess, 75.1ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 hazmat, 77.0ms
# Speed: 7.1ms preprocess, 77.0ms inference, 6.3ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 enemy, 1 hazmat, 75.0ms
# Speed: 7.3ms preprocess, 75.0ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'enemy': 1}
#
# 0: 320x416 1 enemy, 74.9ms
# Speed: 6.8ms preprocess, 74.9ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'enemy': 1}
#
# 0: 320x416 1 enemy, 75.1ms
# Speed: 7.2ms preprocess, 75.1ms inference, 8.9ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'enemy': 1}
#
# 0: 320x416 1 enemy, 74.7ms
# Speed: 7.2ms preprocess, 74.7ms inference, 8.1ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'enemy': 1}
#
# 0: 320x416 1 enemy, 77.3ms
# Speed: 6.9ms preprocess, 77.3ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'enemy': 1}
#
# 0: 320x416 1 enemy, 75.0ms
# Speed: 7.1ms preprocess, 75.0ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'enemy': 1}
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 7.1ms preprocess, 74.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 7.2ms preprocess, 74.9ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 1 mortar, 75.0ms
# Speed: 6.8ms preprocess, 75.0ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'mortar': 1}
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 7.0ms preprocess, 74.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 416)
# [POINT] bravo 최초 통과 → 서버 전송
# [SEND] bravo → 서버 전송 중…
# [Server Response] {"filename":"bravo.json","message":"JSON uploaded successfully"}
#
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 7.5ms preprocess, 74.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 6.9ms preprocess, 74.9ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 7.7ms preprocess, 74.8ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 6.7ms preprocess, 74.8ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.5ms
# Speed: 7.2ms preprocess, 76.5ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 416)
# [POTHOLE] 감지: white_frac=0.020 baseline=0.117 → 회피 수행
# [AVOID] 포트홀 회피 시작 (좌회전)
# [AVOID] 회피 완료
#
# 0: 320x416 1 mortar, 146.8ms
# Speed: 21.5ms preprocess, 146.8ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'mortar': 1}
#
# 0: 320x416 1 mortar, 81.6ms
# Speed: 7.5ms preprocess, 81.6ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'mortar': 1}
#
# 0: 320x416 1 mortar, 74.8ms
# Speed: 7.0ms preprocess, 74.8ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'mortar': 1}
#
# 0: 320x416 (no detections), 74.7ms
# Speed: 7.8ms preprocess, 74.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 7.0ms preprocess, 74.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.0ms
# Speed: 7.2ms preprocess, 76.0ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.3ms
# Speed: 6.9ms preprocess, 75.3ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.7ms
# Speed: 7.6ms preprocess, 74.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.1ms
# Speed: 6.8ms preprocess, 75.1ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.1ms
# Speed: 7.3ms preprocess, 77.1ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.1ms
# Speed: 6.9ms preprocess, 75.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.3ms
# Speed: 7.0ms preprocess, 77.3ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 1 car, 76.7ms
# Speed: 6.9ms preprocess, 76.7ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'car': 1}
#
# 0: 320x416 1 car, 75.9ms
# Speed: 7.8ms preprocess, 75.9ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'car': 1}
#
# 0: 320x416 (no detections), 74.7ms
# Speed: 7.3ms preprocess, 74.7ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 7.2ms preprocess, 74.8ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.0ms
# Speed: 7.0ms preprocess, 75.0ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.0ms
# Speed: 7.0ms preprocess, 75.0ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 6.9ms preprocess, 74.9ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.4ms
# Speed: 7.5ms preprocess, 75.4ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.0ms
# Speed: 7.5ms preprocess, 75.0ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 6.7ms preprocess, 74.8ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.2ms
# Speed: 7.1ms preprocess, 75.2ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.9ms
# Speed: 7.1ms preprocess, 76.9ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.0ms
# Speed: 6.9ms preprocess, 75.0ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.0ms
# Speed: 7.1ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 7.6ms preprocess, 74.8ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.4ms
# Speed: 6.9ms preprocess, 77.4ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.4ms
# Speed: 7.0ms preprocess, 77.4ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 416)
# [POINT] charlie 최초 통과 → 서버 전송
# [SEND] charlie → 서버 전송 중…
# [Server Response] {"filename":"charlie.json","message":"JSON uploaded successfully"}
#
#
# 0: 320x416 (no detections), 72.7ms
# Speed: 6.8ms preprocess, 72.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 73.3ms
# Speed: 7.7ms preprocess, 73.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 73.6ms
# Speed: 7.0ms preprocess, 73.6ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 73.8ms
# Speed: 7.1ms preprocess, 73.8ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 6.9ms preprocess, 74.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.0ms
# Speed: 7.3ms preprocess, 75.0ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.0ms
# Speed: 7.4ms preprocess, 77.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.3ms
# Speed: 8.6ms preprocess, 76.3ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.9ms
# Speed: 6.9ms preprocess, 75.9ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.6ms
# Speed: 7.1ms preprocess, 74.6ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.0ms
# Speed: 7.0ms preprocess, 75.0ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 7.1ms preprocess, 74.9ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 1 hazmat, 75.1ms
# Speed: 7.0ms preprocess, 75.1ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 hazmat, 75.0ms
# Speed: 7.1ms preprocess, 75.0ms inference, 6.8ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 hazmat, 75.1ms
# Speed: 7.0ms preprocess, 75.1ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 hazmat, 74.9ms
# Speed: 7.5ms preprocess, 74.9ms inference, 8.8ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1}
#
# 0: 320x416 1 car, 1 hazmat, 75.0ms
# Speed: 6.9ms preprocess, 75.0ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'car': 1}
#
# 0: 320x416 1 car, 1 hazmat, 74.8ms
# Speed: 7.1ms preprocess, 74.8ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'car': 1}
#
# 0: 320x416 1 car, 1 hazmat, 74.9ms
# Speed: 7.6ms preprocess, 74.9ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'hazmat': 1, 'car': 1}
#
# 0: 320x416 1 car, 75.8ms
# Speed: 7.4ms preprocess, 75.8ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'car': 1}
#
# 0: 320x416 1 car, 76.6ms
# Speed: 7.1ms preprocess, 76.6ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'car': 1}
#
# 0: 320x416 1 car, 1 missile, 75.1ms
# Speed: 6.8ms preprocess, 75.1ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'car': 1, 'missile': 1}
#
# 0: 320x416 1 car, 1 missile, 77.1ms
# Speed: 7.7ms preprocess, 77.1ms inference, 8.2ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'car': 1, 'missile': 1}
#
# 0: 320x416 1 car, 1 missile, 75.1ms
# Speed: 7.1ms preprocess, 75.1ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'car': 1, 'missile': 1}
#
# 0: 320x416 1 car, 1 missile, 74.8ms
# Speed: 7.0ms preprocess, 74.8ms inference, 7.7ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'car': 1, 'missile': 1}
# [POINT] sector9 최초 통과 → 서버 전송
# [SEND] sector9 → 서버 전송 중…
# [Server Response] {"filename":"sector9.json","message":"JSON uploaded successfully"}
#
#
# 0: 320x416 1 car, 75.1ms
# Speed: 7.1ms preprocess, 75.1ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'car': 1}
#
# 0: 320x416 1 car, 74.7ms
# Speed: 7.3ms preprocess, 74.7ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 416)
# [DETECTION] 객체 감지: {'car': 1}
# [POTHOLE] 감지: white_frac=0.038 baseline=0.121 → 회피 수행
# [AVOID] 포트홀 회피 시작 (좌회전)
# [AVOID] 회피 완료
#
# 0: 320x416 (no detections), 146.0ms
# Speed: 11.1ms preprocess, 146.0ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 79.6ms
# Speed: 7.0ms preprocess, 79.6ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 7.2ms preprocess, 74.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 6.9ms preprocess, 74.8ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 7.1ms preprocess, 74.9ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 6.8ms preprocess, 74.9ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 7.2ms preprocess, 74.8ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.1ms
# Speed: 6.8ms preprocess, 75.1ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.1ms
# Speed: 7.2ms preprocess, 77.1ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.6ms
# Speed: 6.9ms preprocess, 76.6ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.0ms
# Speed: 8.4ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.3ms
# Speed: 6.9ms preprocess, 76.3ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 8.0ms preprocess, 74.9ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.0ms
# Speed: 6.8ms preprocess, 75.0ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.7ms
# Speed: 7.2ms preprocess, 77.7ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.8ms
# Speed: 7.0ms preprocess, 76.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 7.6ms preprocess, 74.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.2ms
# Speed: 7.1ms preprocess, 76.2ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.8ms
# Speed: 7.1ms preprocess, 75.8ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.7ms
# Speed: 7.6ms preprocess, 76.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 6.9ms preprocess, 74.8ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.9ms
# Speed: 7.6ms preprocess, 76.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.1ms
# Speed: 6.8ms preprocess, 75.1ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 6.7ms preprocess, 74.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.9ms
# Speed: 7.1ms preprocess, 76.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.1ms
# Speed: 6.8ms preprocess, 76.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.1ms
# Speed: 7.0ms preprocess, 77.1ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.8ms
# Speed: 6.9ms preprocess, 74.8ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.6ms
# Speed: 8.2ms preprocess, 77.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.0ms
# Speed: 7.5ms preprocess, 76.0ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 74.9ms
# Speed: 6.9ms preprocess, 74.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.4ms
# Speed: 7.0ms preprocess, 77.4ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 76.4ms
# Speed: 6.9ms preprocess, 76.4ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 416)
# [END] 프로그램 종료
